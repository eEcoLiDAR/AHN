# %%
import datetime
import getpass
import pathlib

import dcachefs
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # AHN3 processing: extracting computing time and intermediate product sizes

# %% [markdown]
# In this notebook we extract information such as computing times and storage space requirements for all the steps carried out to process the AHN3 dataset. The input LAZ files, the intermediate data products, the final rasterized features as well as the log files containing information about each step's computing time are all stored on the [SURF dCache storage](http://doc.grid.surfsara.nl/en/stable/Pages/Service/system_specifications/dcache_specs.html). The storage is accessed via a macaroon (bearer-token authentication) - see [here](http://doc.grid.surfsara.nl/en/latest/Pages/Advanced/storage_clients/webdav.html#sharing-data-with-macaroons) for more information.

# %% [markdown]
# In order to run this notebook the following packages are required (uncomment and run the following cell in order to install the packages):

# %%
# !pip install pandas matplotlib dcachefs

# %%
# input cell
API_URL = "https://dcacheview.grid.surfsara.nl:22880/api/v1"
WEBDAV_URL = "https://webdav.grid.surfsara.nl:2880"
TOKEN_FILEPATH = "./macaroon.dat"
DCACHE_ROOT_PATH = "/pnfs/grid.sara.nl/data/projects.nl/eecolidar"

# %%
# read token from plain text file
with open(TOKEN_FILEPATH) as f:
    token = f.read().strip()

# %%
# setup filesystem object
fs = dcachefs.dCacheFileSystem(
    api_url=API_URL, 
    webdav_url=WEBDAV_URL,
    token=token
)

# %%
# validate connection
assert fs.ls(DCACHE_ROOT_PATH, detail=False)

# %%
def read_log_file(filepath):
    """ Read log file provided its dCache path. """
    return fs.cat(filepath).decode()
    
    
def extract_time(text):
    """
    Extract execution time from the text of log file.
    
    Parse log timings and extract time delta from initial 
    and final datetimes. Return timing in seconds.  
    """    
    lines = text.splitlines()
    
    start_time = " ".join(lines[0].split()[:2])[:19]
    start_time = datetime.datetime.fromisoformat(start_time)

    end_time = " ".join(lines[-1].split()[:2])[:19]
    end_time = datetime.datetime.fromisoformat(end_time)
    
    return (end_time - start_time).seconds


def extract_times_per_feature(text):
    """
    Extract execution time from a log file for each of the 
    features.

    Return timing in seconds as a dictionary.  
    """
    timing = {}
    for line in text.splitlines():
        ls = line.split()
        if ls[7] == "Extracting" and ls[-1] == "seconds":
            time = float(ls[-2])
            features_list = ls[9:-3]
            features = " ".join(features_list)
            features_clean = features \
                .replace("\"", "") \
                .replace("[", "") \
                .replace("]", "") \
                .replace("'", "") 
            timing[features_clean] = time
    return timing


def extract_times_from_log_files(log_files, feature_breakdown=False):
    """
    Extract execution time from a list of log files. 
    Optionally extract partial timings for the computation of features
    
    Return timing in seconds as a pandas DataFrame.
    """

    # extract timings
    time = []
    for log_file in log_files:
        partial = {}
        txt = read_log_file(log_file)
        total = extract_time(txt)
        if feature_breakdown:
            partial = extract_times_per_feature(txt)
        time.append({"path": log_file, "total": total, **partial}
        )

    time_df = pd.DataFrame(time)
    idx = time_df["path"].apply(lambda x: pathlib.Path(x).stem)
    idx.name = "id"
    time_df.set_index(idx, inplace=True)
    time_df.drop("path", axis=1, inplace=True)
    return time_df

# %% [markdown]
# ## Raw AHN3 LAZ files
#
# Extract size of the raw AHN3 files.

# %%
ahn3_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323"

# %%
files = fs.ls(ahn3_path)

# %%
# get all files with the LAZ extension
ahn3_files = [
    file for file in files if file['name'].lower().endswith(".laz")
]

# %%
ahn3_size_df = pd.DataFrame(ahn3_files)
ahn3_size_df["size"] = ahn3_size_df["size"]/2**30  # to GB 
idx = ahn3_size_df["name"].apply(lambda x: pathlib.Path(x).stem)
idx.name = "id"
ahn3_size_df.set_index(idx, inplace=True)

# %%
ahn3_size_df["size"]
# Out:
# id
# C_38EZ2    1.685300
# C_26DZ1    1.284083
# C_26HN1    2.150178
# C_32GZ2    1.832610
# C_26DZ2    2.480466
#              ...
# C_16AZ1    0.894607
# C_16AZ2    1.154814
# C_44CN1    1.595681
# C_44CN2    1.182035
# C_35AZ1    0.334504
# Name: size, Length: 1367, dtype: float64

# %%
# AHN3 files - file size statistics (in GB)
ahn3_size_df["size"].describe()
# Out:
# count    1367.000000
# mean        1.747396
# std         0.927175
# min         0.000273
# 25%         1.215486
# 50%         1.721688
# 75%         2.193313
# max         5.995163
# Name: size, dtype: float64

# %%
# save to CSV file
ahn3_size_df["size"].sort_index().to_csv("size-GB_ahn3-files.csv")

# %% [markdown]
# ## Retiling

# %%
retiling_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_retiled"

# %%
files = fs.ls(retiling_path)

# %%
# find all files with LOG extension
retiling_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(retiling_log_files)
# Out:
# 1367

# %%
retiling_time_df = extract_times_from_log_files(retiling_log_files)
retiling_time_df
# Out:
#          total
# id
# C_69BN2   1262
# C_67DN1     41
# C_35AN2    389
# C_08DZ2    276
# C_01DZ2    453
# ...        ...
# C_51FZ2   1013
# C_17DZ1    856
# C_08CN2    698
# C_27AN1    905
# C_39GN1   1045
#
# [1367 rows x 1 columns]

# %%
# retiling - execution time statistics (in seconds)
retiling_time_df.describe()
# Out:
#              total
# count  1367.000000
# mean    837.794440
# std     593.002734
# min       2.000000
# 25%     557.500000
# 50%     762.000000
# 75%     992.000000
# max    5940.000000

# %%
# save to CSV file
retiling_time_df.sort_index().to_csv("time-seconds_retiling.csv")

# %%
# check number of tiles (directories) after retiling
tile_paths = [file["name"] for file in files if file["type"] == "directory"]
len(tile_paths)
# Out:
# 37457

# %% [markdown]
# ## Normalization

# %%
normalization_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_normalized"

# %%
files = fs.ls(normalization_path)

# %%
# find all files with LOG extension
normalization_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(normalization_log_files)
# Out:
# 37457

# %%
normalization_time_df = extract_times_from_log_files(normalization_log_files)
normalization_time_df
# Out:
#               total
# id
# tile_126_156     37
# tile_126_157     11
# tile_127_152     56
# tile_127_153     21
# tile_127_154    140
# ...             ...
# tile_390_366    135
# tile_390_367     79
# tile_390_368     46
# tile_390_369     27
# tile_391_363     28
#
# [37457 rows x 1 columns]

# %%
# normalization - execution time statistics (in seconds)
normalization_time_df.describe()
# Out:
#               total
# count  37457.000000
# mean     222.997704
# std       73.408030
# min        9.000000
# 25%      185.000000
# 50%      214.000000
# 75%      254.000000
# max     1099.000000

# %%
# save to CSV file
normalization_time_df.sort_index().to_csv("time-seconds_normalization.csv")

# %%
# find all files with LAZ extension
normalization_size_df = pd.DataFrame(
    [file for file in files if file["name"].lower().endswith(".laz")]
)
normalization_size_df["size"] = normalization_size_df["size"]/2**30  # to GB 
idx = normalization_size_df["name"].apply(lambda x: pathlib.Path(x).stem)
idx.name = "id"
normalization_size_df.set_index(idx, inplace=True)

# %%
normalization_size_df["size"]
# Out:
# id
# tile_126_156    0.018798
# tile_126_157    0.000278
# tile_127_152    0.013544
# tile_127_153    0.005760
# tile_127_154    0.086497
#                   ...
# tile_390_366    0.034329
# tile_390_367    0.025124
# tile_390_368    0.004907
# tile_390_369    0.000009
# tile_391_363    0.002674
# Name: size, Length: 37457, dtype: float64

# %%
# normalization - file size statistics (in GB)
normalization_size_df["size"].describe()
# Out:
# count    3.745700e+04
# mean     1.508583e-01
# std      7.533979e-02
# min      6.072223e-07
# 25%      1.090739e-01
# 50%      1.344187e-01
# 75%      1.784685e-01
# max      1.162908e+00
# Name: size, dtype: float64

# %%
# save to CSV file
normalization_size_df["size"].sort_index().to_csv("size-GB_normalization-output.csv")

# %% [markdown]
# ## Feature extraction - all points

# %%
features_all_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_targets_all"

# %%
files = fs.ls(features_all_path)

# %%
# find all files with LOG extension
features_all_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(features_all_log_files)
# Out:
# 37457

# %%
features_all_time_df = extract_times_from_log_files(features_all_log_files, feature_breakdown=True)

# %%
features_all_time_df
# Out:
#               total  point_density  pulse_penetration_ratio  \
# id
# tile_344_350    251           1.34                    41.75
# tile_240_321    227           1.32                    32.80
# tile_340_359    221           1.19                    29.92
# tile_219_245    314           1.80                    47.82
# tile_159_196     76           0.20                     3.16
# ...             ...            ...                      ...
# tile_277_217    245           1.23                    38.92
# tile_296_282    222           1.46                    33.77
# tile_274_218    179           0.97                    23.41
# tile_294_283    227           1.46                    33.51
# tile_293_284    221           1.29                    31.38
#
#               density_absolute_mean_normalized_height
# id
# tile_344_350                                    41.00
# tile_240_321                                    33.54
# tile_340_359                                    30.27
# tile_219_245                                    49.61
# tile_159_196                                     3.40
# ...                                               ...
# tile_277_217                                    39.90
# tile_296_282                                    32.20
# tile_274_218                                    24.44
# tile_294_283                                    32.41
# tile_293_284                                    31.23
#
# [37457 rows x 4 columns]

# %%
# feature extraction for all points - execution time statistics (in seconds)
features_all_time_df.describe()
# Out:
#               total  point_density  pulse_penetration_ratio  \
# count  37457.000000   37457.000000             37457.000000
# mean     276.504365       1.510156                39.166373
# std       98.427831       0.681952                17.429325
# min       48.000000       0.060000                 0.010000
# 25%      217.000000       1.160000                29.910000
# 50%      256.000000       1.380000                36.250000
# 75%      325.000000       1.750000                46.020000
# max     1431.000000      12.430000               287.670000
#
#        density_absolute_mean_normalized_height
# count                             37457.000000
# mean                                 40.163299
# std                                  18.202233
# min                                   0.030000
# 25%                                  30.360000
# 50%                                  36.960000
# 75%                                  47.270000
# max                                 300.410000

# %%
# save to CSV file
features_all_time_df.sort_index().to_csv("time-seconds_features_all-points.csv")

# %% [markdown]
# ## Feature extraction - vegetation points

# %%
features_veg_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_targets_veg"

# %%
files = fs.ls(features_veg_path)

# %%
# find all files with LOG extension
features_veg_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(features_veg_log_files)
# Out:
# 37457

# %%
features_veg_time_df = extract_times_from_log_files(features_veg_log_files, feature_breakdown=True)

# %%
features_veg_time_df
# Out:
#               total  band_ratio_6<normalized_height  \
# id
# tile_380_318    128                            1.73
# tile_306_344    132                            2.29
# tile_327_368    135                            1.41
# tile_312_260    140                            1.79
# tile_289_270    307                            4.61
# ...             ...                             ...
# tile_294_281    283                            4.22
# tile_381_371    130                            0.28
# tile_382_372     75                            0.03
# tile_383_370    118                            2.12
# tile_379_369    124                            1.99
#
#               band_ratio_3<normalized_height  \
# id
# tile_380_318                            1.31
# tile_306_344                            1.65
# tile_327_368                            1.18
# tile_312_260                            1.20
# tile_289_270                            2.83
# ...                                      ...
# tile_294_281                            2.97
# tile_381_371                            0.29
# tile_382_372                            0.03
# tile_383_370                            1.19
# tile_379_369                            1.27
#
#               band_ratio_5<normalized_height<6  \
# id
# tile_380_318                              0.85
# tile_306_344                              1.09
# tile_327_368                              0.88
# tile_312_260                              0.88
# tile_289_270                              2.47
# ...                                        ...
# tile_294_281                              2.26
# tile_381_371                              0.18
# tile_382_372                              0.03
# tile_383_370                              0.79
# tile_379_369                              0.81
#
#               band_ratio_4<normalized_height<5  \
# id
# tile_380_318                              0.85
# tile_306_344                              0.96
# tile_327_368                              0.86
# tile_312_260                              0.87
# tile_289_270                              2.32
# ...                                        ...
# tile_294_281                              2.28
# tile_381_371                              0.18
# tile_382_372                              0.02
# tile_383_370                              0.86
# tile_379_369                              0.79
#
#               band_ratio_3<normalized_height<4  \
# id
# tile_380_318                              0.84
# tile_306_344                              0.93
# tile_327_368                              0.86
# tile_312_260                              0.87
# tile_289_270                              2.34
# ...                                        ...
# tile_294_281                              2.25
# tile_381_371                              0.18
# tile_382_372                              0.02
# tile_383_370                              0.79
# tile_379_369                              0.77
#
#               band_ratio_2<normalized_height<3  \
# id
# tile_380_318                              0.86
# tile_306_344                              0.99
# tile_327_368                              0.86
# tile_312_260                              0.87
# tile_289_270                              2.32
# ...                                        ...
# tile_294_281                              2.29
# tile_381_371                              0.18
# tile_382_372                              0.02
# tile_383_370                              0.79
# tile_379_369                              0.80
#
#               band_ratio_1<normalized_height<2  \
# id
# tile_380_318                              0.86
# tile_306_344                              0.95
# tile_327_368                              0.86
# tile_312_260                              0.86
# tile_289_270                              2.64
# ...                                        ...
# tile_294_281                              2.25
# tile_381_371                              0.18
# tile_382_372                              0.02
# tile_383_370                              0.78
# tile_379_369                              0.81
#
#               band_ratio_normalized_height<1  \
# id
# tile_380_318                            1.38
# tile_306_344                            1.42
# tile_327_368                            1.18
# tile_312_260                            1.31
# tile_289_270                            3.02
# ...                                      ...
# tile_294_281                            2.85
# tile_381_371                            0.28
# tile_382_372                            0.02
# tile_383_370                            1.27
# tile_379_369                            1.25
#
#               density_absolute_mean_normalized_height  \
# id
# tile_380_318                                     1.73
# tile_306_344                                     3.56
# tile_327_368                                     5.12
# tile_312_260                                     3.72
# tile_289_270                                    32.83
# ...                                               ...
# tile_294_281                                    34.80
# tile_381_371                                     0.36
# tile_382_372                                     0.07
# tile_383_370                                     1.07
# tile_379_369                                     1.51
#
#               entropy_normalized_height  \
# id
# tile_380_318                       0.82
# tile_306_344                       2.44
# tile_327_368                       1.60
# tile_312_260                       1.65
# tile_289_270                       4.54
# ...                                 ...
# tile_294_281                       4.57
# tile_381_371                       0.91
# tile_382_372                       0.11
# tile_383_370                       1.02
# tile_379_369                       0.42
#
#               mean_normalized_height, std_normalized_height, coeff_var_normalized_height  \
# id
# tile_380_318                                               0.22
# tile_306_344                                               0.63
# tile_327_368                                               0.48
# tile_312_260                                               0.44
# tile_289_270                                               1.54
# ...                                                         ...
# tile_294_281                                               1.70
# tile_381_371                                               0.16
# tile_382_372                                               0.09
# tile_383_370                                               0.19
# tile_379_369                                               0.13
#
#               kurto_normalized_height  skew_normalized_height  \
# id
# tile_380_318                     0.76                    1.11
# tile_306_344                     2.42                    3.23
# tile_327_368                     1.59                    2.12
# tile_312_260                     1.42                    1.98
# tile_289_270                     3.50                    4.52
# ...                               ...                     ...
# tile_294_281                     3.42                    4.32
# tile_381_371                     0.71                    1.07
# tile_382_372                     0.14                    0.22
# tile_383_370                     0.77                    1.18
# tile_379_369                     0.38                    0.52
#
#               var_normalized_height  perc_95_normalized_height  \
# id
# tile_380_318                   0.16                       0.21
# tile_306_344                   0.42                       0.47
# tile_327_368                   0.34                       0.41
# tile_312_260                   0.30                       0.38
# tile_289_270                   1.36                       2.08
# ...                             ...                        ...
# tile_294_281                   1.46                       2.13
# tile_381_371                   0.10                       0.11
# tile_382_372                   0.02                       0.06
# tile_383_370                   0.13                       0.16
# tile_379_369                   0.10                       0.17
#
#               perc_75_normalized_height  perc_50_normalized_height  \
# id
# tile_380_318                       0.22                       0.21
# tile_306_344                       0.48                       0.45
# tile_327_368                       0.39                       0.38
# tile_312_260                       0.38                       0.37
# tile_289_270                       2.15                       2.18
# ...                                 ...                        ...
# tile_294_281                       2.08                       2.09
# tile_381_371                       0.11                       0.11
# tile_382_372                       0.06                       0.06
# tile_383_370                       0.16                       0.16
# tile_379_369                       0.17                       0.17
#
#               perc_25_normalized_height
# id
# tile_380_318                       0.20
# tile_306_344                       0.48
# tile_327_368                       0.39
# tile_312_260                       0.38
# tile_289_270                       2.21
# ...                                 ...
# tile_294_281                       2.06
# tile_381_371                       0.12
# tile_382_372                       0.06
# tile_383_370                       0.17
# tile_379_369                       0.17
#
# [37457 rows x 19 columns]

# %%
# feature extraction for vegetation points , part 1 - execution time statistics (in seconds)
features_veg_time_df.describe()
# Out:
#               total  band_ratio_6<normalized_height  \
# count  37457.000000                    37457.000000
# mean     169.801399                        2.375520
# std       69.736211                        1.479243
# min       56.000000                        0.000000
# 25%      127.000000                        1.430000
# 50%      151.000000                        2.060000
# 75%      192.000000                        3.000000
# max     1220.000000                       26.060000
#
#        band_ratio_3<normalized_height  band_ratio_5<normalized_height<6  \
# count                    37457.000000                      37457.000000
# mean                         1.716682                          1.265703
# std                          0.931172                          0.740935
# min                          0.000000                          0.000000
# 25%                          1.140000                          0.800000
# 50%                          1.540000                          1.110000
# 75%                          2.120000                          1.580000
# max                         13.550000                         11.130000
#
#        band_ratio_4<normalized_height<5  band_ratio_3<normalized_height<4  \
# count                      37457.000000                      37457.000000
# mean                           1.258591                          1.257629
# std                            0.739832                          0.738794
# min                            0.000000                          0.000000
# 25%                            0.790000                          0.790000
# 50%                            1.110000                          1.100000
# 75%                            1.570000                          1.570000
# max                           10.600000                         10.580000
#
#        band_ratio_2<normalized_height<3  band_ratio_1<normalized_height<2  \
# count                      37457.000000                      37457.000000
# mean                           1.257005                          1.256564
# std                            0.739076                          0.738696
# min                            0.000000                          0.000000
# 25%                            0.790000                          0.790000
# 50%                            1.100000                          1.100000
# 75%                            1.570000                          1.570000
# max                           10.070000                         10.550000
#
#        band_ratio_normalized_height<1  \
# count                    37457.000000
# mean                         1.734441
# std                          0.955720
# min                          0.000000
# 25%                          1.150000
# 50%                          1.550000
# 75%                          2.150000
# max                         13.480000
#
#        density_absolute_mean_normalized_height  entropy_normalized_height  \
# count                             37457.000000               37457.000000
# mean                                 11.220281                   2.534326
# std                                  13.214067                   1.464235
# min                                   0.030000                   0.000000
# 25%                                   2.680000                   1.520000
# 50%                                   6.780000                   2.290000
# 75%                                  14.420000                   3.350000
# max                                 186.290000                  12.910000
#
#        mean_normalized_height, std_normalized_height, coeff_var_normalized_height  \
# count                                       37457.000000
# mean                                            0.793532
# std                                             0.642820
# min                                             0.010000
# 25%                                             0.380000
# 50%                                             0.610000
# 75%                                             1.010000
# max                                             8.740000
#
#        kurto_normalized_height  skew_normalized_height  var_normalized_height  \
# count             37457.000000            37457.000000           37457.000000
# mean                  2.064432                2.826204               0.600087
# std                   1.091089                1.379120               0.508892
# min                   0.000000                0.000000               0.000000
# 25%                   1.320000                1.880000               0.270000
# 50%                   1.930000                2.730000               0.450000
# 75%                   2.690000                3.690000               0.770000
# max                   9.390000               10.650000               6.750000
#
#        perc_95_normalized_height  perc_75_normalized_height  \
# count               37457.000000               37457.000000
# mean                    0.808412                   0.802635
# std                     0.760886                   0.758925
# min                     0.040000                   0.040000
# 25%                     0.310000                   0.310000
# 50%                     0.570000                   0.560000
# 75%                     1.020000                   1.010000
# max                    11.220000                  11.190000
#
#        perc_50_normalized_height  perc_25_normalized_height
# count               37457.000000               37457.000000
# mean                    0.792852                   0.802347
# std                     0.755342                   0.760354
# min                     0.040000                   0.040000
# 25%                     0.300000                   0.310000
# 50%                     0.550000                   0.560000
# 75%                     1.000000                   1.010000
# max                    11.070000                  14.860000

# %%
# save to CSV file
features_veg_time_df.sort_index().to_csv("time-seconds_features_veg-points-1.csv")

# %% [markdown]
# ## Feature extraction - vegetation points - additional features

# %%
features_veg_2_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_targets_veg_additional-features"

# %%
files = fs.ls(features_veg_2_path)

# %%
# find all files with LOG extension
features_veg_2_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(features_veg_2_log_files)
# Out:
# 37457

# %%
features_veg_2_time_df = extract_times_from_log_files(features_veg_2_log_files, feature_breakdown=True)

# %%
features_veg_2_time_df
# Out:
#               total  \
# id
# tile_260_386    215
# tile_266_198    272
# tile_266_181    212
# tile_270_270    179
# tile_270_269    179
# ...             ...
# tile_388_367    325
# tile_385_330    285
# tile_384_371    285
# tile_385_331    307
# tile_385_332    307
#
#               eigenv_1, eigenv_2, eigenv_3, normal_vector_1, normal_vector_2, normal_vector_3, slope  \
# id
# tile_260_386                                               7.83
# tile_266_198                                               7.83
# tile_266_181                                               3.69
# tile_270_270                                               3.18
# tile_270_269                                               2.21
# ...                                                         ...
# tile_388_367                                               5.32
# tile_385_330                                               0.97
# tile_384_371                                               1.28
# tile_385_331                                               2.07
# tile_385_332                                               3.94
#
#               band_ratio_20<normalized_height  \
# id
# tile_260_386                             2.70
# tile_266_198                             2.73
# tile_266_181                             1.37
# tile_270_270                             1.19
# tile_270_269                             0.81
# ...                                       ...
# tile_388_367                             1.58
# tile_385_330                             0.02
# tile_384_371                             0.48
# tile_385_331                             0.71
# tile_385_332                             1.39
#
#               band_ratio_5<normalized_height<20  \
# id
# tile_260_386                               1.92
# tile_266_198                               1.89
# tile_266_181                               1.02
# tile_270_270                               0.75
# tile_270_269                               0.52
# ...                                         ...
# tile_388_367                               1.03
# tile_385_330                               0.01
# tile_384_371                               0.30
# tile_385_331                               0.43
# tile_385_332                               0.85
#
#               band_ratio_normalized_height<5  median_normalized_height  \
# id
# tile_260_386                            2.65                      1.34
# tile_266_198                            2.45                      1.77
# tile_266_181                            1.52                      1.00
# tile_270_270                            1.14                      0.20
# tile_270_269                            0.86                      0.17
# ...                                      ...                       ...
# tile_388_367                            1.50                      0.12
# tile_385_330                            0.01                      0.01
# tile_384_371                            0.41                      0.30
# tile_385_331                            0.68                      0.06
# tile_385_332                            1.39                      0.10
#
#               max_normalized_height, min_normalized_height, range_normalized_height  \
# id
# tile_260_386                                               0.78
# tile_266_198                                               1.12
# tile_266_181                                               0.50
# tile_270_270                                               0.07
# tile_270_269                                               0.47
# ...                                                         ...
# tile_388_367                                               0.05
# tile_385_330                                               0.01
# tile_384_371                                               0.11
# tile_385_331                                               0.03
# tile_385_332                                               0.43
#
#               sigma_z  point_density
# id
# tile_260_386     7.19           0.73
# tile_266_198    10.94           1.67
# tile_266_181     3.38           0.40
# tile_270_270     2.01           0.10
# tile_270_269     2.02           0.09
# ...               ...            ...
# tile_388_367     1.84           0.10
# tile_385_330     2.49           0.10
# tile_384_371     2.02           0.08
# tile_385_331     1.90           0.07
# tile_385_332     2.01           0.10
#
# [37457 rows x 9 columns]

# %%
# feature extraction for vegetation points , part 2 - execution time statistics (in seconds)
features_veg_2_time_df.describe()
# Out:
#               total  \
# count  37457.000000
# mean     278.468697
# std     1916.537248
# min       13.000000
# 25%      163.000000
# 50%      230.000000
# 75%      306.000000
# max    83123.000000
#
#        eigenv_1, eigenv_2, eigenv_3, normal_vector_1, normal_vector_2, normal_vector_3, slope  \
# count                                       37457.000000
# mean                                            5.398221
# std                                             3.382620
# min                                             0.050000
# 25%                                             3.380000
# 50%                                             4.590000
# 75%                                             6.480000
# max                                            47.900000
#
#        band_ratio_20<normalized_height  band_ratio_5<normalized_height<20  \
# count                     37457.000000                       37457.000000
# mean                          1.856082                           1.325510
# std                           1.061543                           0.819839
# min                           0.000000                           0.000000
# 25%                           1.220000                           0.820000
# 50%                           1.630000                           1.140000
# 75%                           2.240000                           1.620000
# max                          14.510000                           9.960000
#
#        band_ratio_normalized_height<5  median_normalized_height  \
# count                    37457.000000              37457.000000
# mean                         1.811634                  0.920778
# std                          1.040261                  0.706052
# min                          0.000000                  0.000000
# 25%                          1.180000                  0.470000
# 50%                          1.600000                  0.730000
# 75%                          2.220000                  1.160000
# max                         14.890000                  7.820000
#
#        max_normalized_height, min_normalized_height, range_normalized_height  \
# count                                       37457.000000
# mean                                            0.554372
# std                                             0.541779
# min                                             0.010000
# 25%                                             0.200000
# 50%                                             0.380000
# 75%                                             0.700000
# max                                             7.890000
#
#             sigma_z  point_density
# count  37457.000000   37457.000000
# mean       4.222949       0.456549
# std        2.657795       0.468378
# min        1.610000       0.050000
# 25%        2.570000       0.160000
# 50%        3.360000       0.300000
# 75%        4.840000       0.560000
# max       36.320000       7.310000

# %%
# save to CSV file
features_veg_2_time_df.sort_index().to_csv("time-seconds_features_veg-points-2.csv")

# %% [markdown]
# ## Geotiff creation - all points

# %%
geotiff_all_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_geotiff_all"

# %%
files = fs.ls(geotiff_all_path)

# %%
# find all files with LOG extension
geotiff_all_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(geotiff_all_log_files)
# Out:
# 3

# %%
geotiff_all_time_df = extract_times_from_log_files(geotiff_all_log_files)
geotiff_all_time_df
# Out:
#                                          total
# id
# point_density                            20205
# density_absolute_mean_normalized_height  20313
# pulse_penetration_ratio                  21106

# %%
# geotiff creation for all-point based features - execution time statistics (in seconds)
geotiff_all_time_df.describe()
# Out:
#               total
# count      3.000000
# mean   20541.333333
# std      491.988143
# min    20205.000000
# 25%    20259.000000
# 50%    20313.000000
# 75%    20709.500000
# max    21106.000000

# %%
# save to CSV file
geotiff_all_time_df.sort_index().to_csv("time-seconds_geotiff_all-points.csv")

# %%
# find all files with TIF extension
geotiff_all_size_df = pd.DataFrame(
    [file for file in files if file["name"].lower().endswith(".tif")]
)
geotiff_all_size_df["size"] = geotiff_all_size_df["size"]/2**30  # to GB 
idx = geotiff_all_size_df["name"].apply(lambda x: pathlib.Path(x).stem)
idx.name = "id"
geotiff_all_size_df.set_index(idx, inplace=True)

# %%
geotiff_all_size_df["size"]
# Out:
# id
# ahn3_feat_10m_1m_all_TILE_000_BAND_point_density                              0.887047
# ahn3_feat_10m_1m_all_TILE_000_BAND_density_absolute_mean_normalized_height    0.822255
# ahn3_feat_10m_1m_all_TILE_000_BAND_pulse_penetration_ratio                    0.974467
# Name: size, dtype: float64

# %%
# geotiff creation for all-point based features - file size statistics (in GB)
geotiff_all_size_df["size"].describe()
# Out:
# count    3.000000
# mean     0.894590
# std      0.076386
# min      0.822255
# 25%      0.854651
# 50%      0.887047
# 75%      0.930757
# max      0.974467
# Name: size, dtype: float64

# %%
# save to CSV file
geotiff_all_size_df["size"].sort_index().to_csv("size-GB_geotiff-all-output.csv")

# %% [markdown]
# ## Geotiff creation - vegetation points

# %%
geotiff_veg_path = f"{DCACHE_ROOT_PATH}/01_Escience/ALS/Netherlands/ahn3_current/ahn3_current_TOP10NL_ud20200323_geotiff_veg/"

# %%
files = fs.ls(geotiff_veg_path)

# %%
# find all files with LOG extension
geotiff_veg_log_files = [
    file["name"] for file in files if file["name"].lower().endswith(".log")
]
len(geotiff_veg_log_files)
# Out:
# 33

# %%
geotiff_veg_time_df = extract_times_from_log_files(geotiff_veg_log_files)
geotiff_veg_time_df
# Out:
#                                          total
# id
# band_ratio_normalized_height%3C5         20412
# band_ratio_1%3Cnormalized_height%3C2     20156
# band_ratio_6%3Cnormalized_height         20925
# skew_normalized_height                   20360
# std_normalized_height                    20327
# entropy_normalized_height                20211
# mean_normalized_height                   20627
# perc_95_normalized_height                20368
# band_ratio_3%3Cnormalized_height         20122
# band_ratio_4%3Cnormalized_height%3C5     20378
# density_absolute_mean_normalized_height  20445
# band_ratio_3%3Cnormalized_height%3C4     20675
# coeff_var_normalized_height              20582
# var_normalized_height                    20584
# band_ratio_2%3Cnormalized_height%3C3     20591
# band_ratio_normalized_height%3C1         20980
# perc_50_normalized_height                21028
# perc_75_normalized_height                21775
# kurto_normalized_height                  20860
# perc_25_normalized_height                20849
# band_ratio_5%3Cnormalized_height%3C6     21047
# eigenv_2                                 20193
# eigenv_1                                 20301
# median_normalized_height                 20457
# max_normalized_height                    20636
# eigenv_3                                 20725
# normal_vector_2                          21253
# point_density                            21344
# normal_vector_3                          21024
# normal_vector_1                          21188
# sigma_z                                  21978
# band_ratio_20%3Cnormalized_height        19800
# band_ratio_5%3Cnormalized_height%3C20    20357

# %%
# geotiff creation for vegetation-based features - execution time statistics (in seconds)
geotiff_veg_time_df.describe()
# Out:
#               total
# count     33.000000
# mean   20683.575758
# std      473.917255
# min    19800.000000
# 25%    20360.000000
# 50%    20591.000000
# 75%    20980.000000
# max    21978.000000

# %%
# save to CSV file
geotiff_veg_time_df.sort_index().to_csv("time-seconds_geotiff_veg-points.csv")

# %%
# find all files with TIF extension
geotiff_veg_size_df = pd.DataFrame(
    [file for file in files if file["name"].lower().endswith(".tif")]
)
geotiff_veg_size_df["size"] = geotiff_veg_size_df["size"]/2**30  # to GB 
idx = geotiff_veg_size_df["name"].apply(lambda x: pathlib.Path(x).stem)
idx.name = "id"
geotiff_veg_size_df.set_index(idx, inplace=True)

# %%
geotiff_veg_size_df["size"]
# Out:
# id
# ahn3_feat_10m_1m_veg_TILE_000_BAND_mean_normalized_height                     1.007954
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_1%3Cnormalized_height%3C2       0.652252
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_6%3Cnormalized_height           0.470933
# ahn3_feat_10m_1m_veg_TILE_000_BAND_skew_normalized_height                     0.994300
# ahn3_feat_10m_1m_veg_TILE_000_BAND_std_normalized_height                      0.995969
# ahn3_feat_10m_1m_veg_TILE_000_BAND_entropy_normalized_height                  0.718389
# ahn3_feat_10m_1m_veg_TILE_000_BAND_perc_95_normalized_height                  0.916978
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_3%3Cnormalized_height           0.539743
# ahn3_feat_10m_1m_veg_TILE_000_BAND_density_absolute_mean_normalized_height    0.719107
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_4%3Cnormalized_height%3C5       0.496363
# ahn3_feat_10m_1m_veg_TILE_000_BAND_coeff_var_normalized_height                0.956170
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_2%3Cnormalized_height%3C3       0.575166
# ahn3_feat_10m_1m_veg_TILE_000_BAND_var_normalized_height                      1.036336
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_3%3Cnormalized_height%3C4       0.522074
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_normalized_height%3C1           0.686354
# ahn3_feat_10m_1m_veg_TILE_000_BAND_perc_50_normalized_height                  0.747719
# ahn3_feat_10m_1m_veg_TILE_000_BAND_perc_75_normalized_height                  0.787229
# ahn3_feat_10m_1m_veg_TILE_000_BAND_kurto_normalized_height                    0.967595
# ahn3_feat_10m_1m_veg_TILE_000_BAND_perc_25_normalized_height                  0.753215
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_5%3Cnormalized_height%3C6       0.480850
# ahn3_feat_10m_1m_veg_TILE_000_BAND_eigenv_2                                   1.035989
# ahn3_feat_10m_1m_veg_TILE_000_BAND_eigenv_1                                   1.024161
# ahn3_feat_10m_1m_veg_TILE_000_BAND_median_normalized_height                   0.747719
# ahn3_feat_10m_1m_veg_TILE_000_BAND_max_normalized_height                      0.757905
# ahn3_feat_10m_1m_veg_TILE_000_BAND_eigenv_3                                   1.086261
# ahn3_feat_10m_1m_veg_TILE_000_BAND_normal_vector_3                            0.961353
# ahn3_feat_10m_1m_veg_TILE_000_BAND_normal_vector_1                            1.101807
# ahn3_feat_10m_1m_veg_TILE_000_BAND_normal_vector_2                            1.078190
# ahn3_feat_10m_1m_veg_TILE_000_BAND_point_density                              0.549778
# ahn3_feat_10m_1m_veg_TILE_000_BAND_sigma_z                                    1.001573
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_20%3Cnormalized_height          0.208977
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_5%3Cnormalized_height%3C20      0.493397
# ahn3_feat_10m_1m_veg_TILE_000_BAND_band_ratio_normalized_height%3C5           0.508566
# Name: size, dtype: float64

# %%
# geotiff creation for vegetation-based features - file size statistics (in GB)
geotiff_veg_size_df["size"].describe()
# Out:
# count    33.000000
# mean      0.775163
# std       0.236534
# min       0.208977
# 25%       0.549778
# 50%       0.753215
# 75%       0.995969
# max       1.101807
# Name: size, dtype: float64

# %%
# save to CSV file
geotiff_veg_size_df["size"].sort_index().to_csv("size-GB_geotiff-veg-output.csv")
